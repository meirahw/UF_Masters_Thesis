# %% [markdown]
# ### append lat lon (copied from original script in onedrive)

# %%
# import numpy
import numpy as np

# import netcdf
import netCDF4
from netCDF4 import Dataset

# import os
import os

# %%
# create function that appends lat/lon to ERO netcdf
def append_EROs(ERO_append):

    # print keys of original file
    ERO_append.variables.keys()

    # print dimensions of original file
    ERO_append.dimensions.items()

    # add lat/lon variables with units and name
    lat = ERO_append.createVariable('lat', np.float32, ('lat',))
    lat.units = 'degrees_north'
    lat.long_name = 'latitude'
    lon = ERO_append.createVariable('lon', np.float32, ('lon',))
    lon.units = 'degrees_east'
    lon.long_name = 'longitude'

    # make sure lat/lon exist as variables now; see lat/lon starting points, deltas
    print(ERO_append)

    # create lat and lon variables based on ERO info
    lat[:] = np.linspace(25, 25+0.09*276, 276)
    lon[:] = np.linspace(-129.8, -129.8+0.09*721, 721)

    # make sure lat/lon were added correctly
    #print(ERO_append)

    # close file after saving
    ERO_append.close()

# %%
# append all files with lat and lon in folder
for filename in os.listdir(r'/blue/emullens/meirahwilliamson/netcdf_ero_cleaned/jja'):
    
    ERO_file = Dataset(r'/blue/emullens/meirahwilliamson/netcdf_ero_cleaned/jja/' + filename, 'a')
    
    append_EROs(ERO_file)
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2020072312_e2020072412_vhr09_240000L_20200724_120000V_pairs.nc generated 20201118_070330 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A235324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2020072312_e2020072412_vhr09_240000L_20200724_120000V_pairs.nc generated 20201118_070330 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A235324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2019072912_e2019073012_vhr09_240000L_20190730_120000V_pairs.nc generated 20201023_201831 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2019072912_e2019073012_vhr09_240000L_20190730_120000V_pairs.nc generated 20201023_201831 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2019070912_e2019071012_vhr09_240000L_20190710_120000V_pairs.nc generated 20201023_185605 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2019070912_e2019071012_vhr09_240000L_20190710_120000V_pairs.nc generated 20201023_185605 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2020080512_e2020080612_vhr09_240000L_20200806_120000V_pairs.nc generated 20201118_081732 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2020080512_e2020080612_vhr09_240000L_20200806_120000V_pairs.nc generated 20201118_081732 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2020081712_e2020081812_vhr09_240000L_20200818_120000V_pairs.nc generated 20201118_092510 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2020081712_e2020081812_vhr09_240000L_20200818_120000V_pairs.nc generated 20201118_092510 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2019081812_e2019081912_vhr09_240000L_20190819_120000V_pairs.nc generated 20201023_214344 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2019081812_e2019081912_vhr09_240000L_20190819_120000V_pairs.nc generated 20201023_214344 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2017081512_e2017081612_vhr09_240000L_20170816_120000V_pairs.nc generated 20201017_134224 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2017081512_e2017081612_vhr09_240000L_20170816_120000V_pairs.nc generated 20201017_134224 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2018082812_e2018082912_vhr09_240000L_20180829_120000V_pairs.nc generated 20201021_012556 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2018082812_e2018082912_vhr09_240000L_20180829_120000V_pairs.nc generated 20201021_012556 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2018061212_e2018061312_vhr09_240000L_20180613_120000V_pairs.nc generated 20201020_193307 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A235324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2018061212_e2018061312_vhr09_240000L_20180613_120000V_pairs.nc generated 20201020_193307 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A235324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2020070412_e2020070512_vhr09_240000L_20200705_120000V_pairs.nc generated 20201118_052514 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_
UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2019080312_e2019080412_vhr09_240000L_20190804_120000V_pairs.nc generated 20201023_203716 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2018080812_e2018080912_vhr09_240000L_20180809_120000V_pairs.nc generated 20201021_000224 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2018080812_e2018080912_vhr09_240000L_20180809_120000V_pairs.nc generated 20201021_000224 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2017070412_e2017070512_vhr09_240000L_20170705_120000V_pairs.nc generated 20201017_104053 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2017070412_e2017070512_vhr09_240000L_20170705_120000V_pairs.nc generated 20201017_104053 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
# ...
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2017081712_e2017081812_vhr09_240000L_20170818_120000V_pairs.nc generated 20201017_135214 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2017081712_e2017081812_vhr09_240000L_20170818_120000V_pairs.nc generated 20201017_135214 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2017072012_e2017072112_vhr09_240000L_20170721_120000V_pairs.nc generated 20201017_114911 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2017072012_e2017072112_vhr09_240000L_20170721_120000V_pairs.nc generated 20201017_114911 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2020073012_e2020073112_vhr09_240000L_20200731_120000V_pairs.nc generated 20201118_074318 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A325324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2020073012_e2020073112_vhr09_240000L_20200731_120000V_pairs.nc generated 20201118_074318 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A325324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2020071812_e2020071912_vhr09_240000L_20200719_120000V_pairs.nc generated 20201118_063831 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A285324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2020071812_e2020071912_vhr09_240000L_20200719_120000V_pairs.nc generated 20201118_063831 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A285324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2017080712_e2017080812_vhr09_240000L_20170808_120000V_pairs.nc generated 20201017_130643 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2017080712_e2017080812_vhr09_240000L_20170808_120000V_pairs.nc generated 20201017_130643 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2019061612_e2019061712_vhr09_240000L_20190617_120000V_pairs.nc generated 20201023_171145 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A265324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2019061612_e2019061712_vhr09_240000L_20190617_120000V_pairs.nc generated 20201023_171145 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A265324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2017073112_e2017080112_vhr09_240000L_20170801_120000V_pairs.nc generated 20201017_124038 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2017073112_e2017080112_vhr09_240000L_20170801_120000V_pairs.nc generated 20201017_124038 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2017062212_e2017062312_vhr09_240000L_20170623_120000V_pairs.nc generated 20201017_095911 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2017062212_e2017062312_vhr09_240000L_20170623_120000V_pairs.nc generated 20201017_095911 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2017071812_e2017071912_vhr11_240000L_20170719_120000V_pairs.nc generated 20201017_113941 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     FileOrigins: File /export/hpc-lw-dtbdev5/wpc_cpgffh/gribs/ERO_verif/ERO_verif_day1_ALLTEST//grid_stat_ALL_ERO_s2017071812_e2017071912_vhr11_240000L_20170719_120000V_pairs.nc generated 20201017_113941 UTC on host hpc-lw-dtbdev5.ncep.noaa.gov by the MET grid_stat tool
#     MET_version: V9.0.1
#     MET_tool: grid_stat
#     model: WRF
#     obtype: ANALYS
#     Projection: LatLon
#     lat_ll: 25.000000 degrees_north
#     lon_ll: -129.800000 degrees_east
#     delta_lat: 0.090000 degrees
#     delta_lon: 0.090000 degrees
#     Nlat: 276 grid_points
#     Nlon: 721 grid_points
#     dimensions(sizes): lat(276), lon(721)
#     variables(dimensions): float32 FCST_ERO_Surface_FULL(lat,lon), float32 OBS_ALL_A365324_FULL_MAX_49(lat,lon), float32 lat(lat), float32 lon(lon)
#     groups:
